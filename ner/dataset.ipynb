# %%
import pandas as pd

# %%
sentences = [
    ["Hoverla", "the", "highest", "peak", "in", "the", "Carpathian", "Mountains,", "offers", "breathtaking", "views", "of", "the", "surrounding", "landscape."],
    ["Sinyak", "is", "a", "challenging", "mountain", "to", "climb,", "but", "the", "sense", "of", "accomplishment", "at", "the", "summit", "is", "worth", "the", "effort."],
    ["Makovytsia", "with", "its", "lush", "green", "slopes,", "is", "a", "haven", "for", "nature", "enthusiasts", "and", "hikers", "alike."],
    ["Petros", "standing", "proudly", "in", "the", "distance,", "beckons", "adventurers", "to", "explore", "its", "rugged", "trails."],
    ["Shpici", "although", "not", "as", "well-known,", "has", "its", "own", "unique", "charm", "and", "allure", "for", "those", "seeking", "solitude."],
    ["Exploring", "the", "dense", "forests", "around", "Hoverla", "reveals", "a", "diverse", "ecosystem", "of", "flora", "and", "fauna."],
    ["Sinyak", "rocky", "terrain", "poses", "a", "thrilling", "adventure", "for", "rock", "climbers", "seeking", "an", "adrenaline", "rush."],
    ["Makovytsia", "surrounded", "by", "alpine", "meadows,", "is", "a", "picturesque", "destination", "for", "a", "relaxing", "getaway."],
    ["Petros", "is", "often", "shrouded", "in", "mist,", "adding", "an", "air", "of", "mystery", "to", "its", "already", "majestic", "presence."],
    ["Shpici", "serene", "surroundings", "make", "it", "an", "ideal", "spot", "for", "meditation", "and", "self-reflection."],
    ["Nestled", "in", "the", "Carpathians,", "Hoverla", "is", "a", "hotspot", "for", "both", "winter", "and", "summer", "outdoor", "activities."],
    ["Sinyak", "snow-capped", "peaks", "create", "a", "stunning", "contrast", "against", "the", "deep", "blue", "sky."],
    ["Makovytsia", "known", "for", "its", "wildflowers,", "becomes", "a", "vibrant", "tapestry", "during", "the", "spring", "season."],
    ["Petros", "with", "its", "imposing", "cliffs,", "is", "a", "popular", "destination", "for", "daredevil", "climbers."],
    ["Shpici", "remote", "location", "attracts", "intrepid", "explorers", "seeking", "untouched", "wilderness."],
    ["Hoverla", "summit", "provides", "an", "unobstructed", "panorama", "of", "the", "surrounding", "mountain", "range."],
    ["Sinyak", "valleys", "are", "home", "to", "pristine", "streams", "and", "cascading", "waterfalls,", "adding", "to", "its", "allure."],
    ["Makovytsia", "trails", "wind", "through", "ancient", "forests,", "revealing", "the", "mountain's", "rich", "biodiversity."],
    ["Petros", "with", "its", "challenging", "ascent,", "is", "a", "favorite", "among", "mountaineering", "enthusiasts."],
    ["Shpici", "alpine", "lakes", "are", "hidden", "gems,", "offering", "a", "peaceful", "retreat", "for", "nature", "lovers."],
    ["Hoverla", "standing", "tall,", "is", "a", "symbol", "of", "the", "natural", "beauty", "that", "the", "Carpathian", "Mountains", "hold."],
    ["Sinyak", "rugged", "beauty", "is", "a", "testament", "to", "the", "untamed", "wilderness", "found", "in", "the", "region."],
    ["Makovytsia", "meadows", "are", "alive", "with", "the", "buzzing", "sounds", "of", "insects", "and", "the", "chirping", "of", "birds."],
    ["Petros", "named", "after", "a", "legendary", "figure,", "is", "steeped", "in", "folklore", "and", "local", "traditions."],
    ["Shpici", "though", "less", "visited,", "captivates", "those", "who", "seek", "solitude", "and", "a", "connection", "with", "nature."],
    ["Climbing", "Hoverla", "during", "the", "winter", "months", "provides", "a", "completely", "different", "but", "equally", "enchanting", "experience."],
    ["Sinyak", "bathed", "in", "the", "warm", "hues", "of", "the", "setting", "sun,", "is", "a", "sight", "to", "behold."],
    ["Makovytsia", "foothills", "are", "adorned", "with", "charming", "villages,", "welcoming", "visitors", "with", "hospitality."],
    ["Petros", "a", "challenging", "climb,", "rewards", "adventurers", "with", "unparalleled", "views", "of", "the", "Carpathians."],
    ["Shpici", "trails", "offer", "a", "chance", "to", "encounter", "diverse", "wildlife,", "from", "elusive", "deer", "to", "soaring", "eagles."],
    ["Hoverla", "slopes", "are", "adorned", "with", "vibrant", "wildflowers", "during", "the", "summer", "months."],
    ["Sinyak", "rocky", "outcrops", "are", "a", "playground", "for", "skilled", "rock", "climbers", "and", "bouldering", "enthusiasts."],
    ["Makovytsia", "with", "its", "accessible", "trails,", "is", "suitable", "for", "hikers", "of", "all", "skill", "levels."],
    ["Petros", "summit,", "kissed", "by", "the", "first", "light", "of", "dawn,", "is", "a", "magical", "moment", "for", "early", "risers."],
    ["Shpici", "hidden", "away", "from", "the", "tourist", "crowds,", "provides", "a", "tranquil", "escape", "for", "those", "seeking", "solitude."],
    ["The", "valleys", "surrounding", "Hoverla", "are", "home", "to", "unique", "plant", "species", "adapted", "to", "the", "mountainous", "climate."],
    ["Sinyak", "craggy", "peaks", "are", "silhouetted", "against", "the", "evening", "sky,", "creating", "a", "dramatic", "scene."],
    ["Makovytsia", "diverse", "ecosystem", "supports", "a", "variety", "of", "wildlife,", "from", "butterflies", "to", "elusive", "mammals."],
    ["Petros", "with", "its", "challenging", "ascent,", "attracts", "climbers", "from", "around", "the", "world."],
    ["Shpici", "remote", "location", "allows", "for", "stargazing,", "offering", "a", "clear", "view", "of", "the", "night", "sky."],
    ["Hoverla", "with", "its", "snow-covered", "slopes,", "transforms", "into", "a", "winter", "wonderland", "during", "the", "colder", "months."],
    ["Sinyak", "meandering", "trails", "lead", "to", "hidden", "viewpoints,", "rewarding", "hikers", "with", "stunning", "vistas."],
    ["Makovytsia", "alpine", "lakes", "reflect", "the", "surrounding", "peaks,", "creating", "a", "mirror-like", "effect."],
    ["Petros", "ancient", "rock", "formations", "tell", "a", "geological", "story", "that", "spans", "thousands", "of", "years."],
    ["Shpici", "with", "its", "untouched", "landscapes,", "is", "a", "haven", "for", "photographers", "capturing", "the", "raw", "beauty", "of", "nature."],
    ["Exploring", "Hoverla's", "foothills", "reveals", "charming", "villages", "and", "a", "rich", "cultural", "heritage."],
    ["Sinyak", "with", "its", "challenging", "terrain,", "is", "a", "playground", "for", "adrenaline", "junkies", "seeking", "adventure."],
    ["Makovytsia", "blanketed", "in", "snow", "during", "winter,", "is", "a", "serene", "and", "peaceful", "destination."],
    ["Petros", "towering", "cliffs", "provide", "nesting", "grounds", "for", "birds,", "creating", "a", "birdwatcher's", "paradise."],
    ["Shpici", "embraced", "by", "the", "tranquility", "of", "nature,", "invites", "visitors", "to", "disconnect", "and", "rejuvenate."],
    ["The", "Carpathian", "Mountains,", "encompassing", "Hoverla,", "are", "known", "for", "their", "diverse", "ecosystems", "and", "stunning", "landscapes."],
    ["With", "its", "challenging", "trails,", "Sinyak", "Mountain", "attracts", "adventure", "enthusiasts", "from", "around", "the", "world."],
    ["Makovytsia", "surrounded", "by", "alpine", "meadows,", "is", "a", "hidden", "gem", "in", "the", "Carpathian", "region."],
    ["Adventurers", "often", "seek", "the", "rugged", "trails", "of", "Petros", "for", "an", "adrenaline-fueled", "hiking", "experience."],
    ["Amidst", "the", "tranquility,", "Shpici", "mountain", "stands", "tall,", "offering", "panoramic", "views", "of", "the", "surrounding", "valleys."],
    ["Hoverla", "a", "symbol", "of", "natural", "beauty,", "invites", "hikers", "to", "explore", "its", "breathtaking", "slopes."],
    ["Rock", "climbers", "admire", "Sinyak's", "rocky", "terrain,", "testing", "their", "skills", "against", "its", "formidable", "peaks."],
    ["The", "vibrant", "wildflowers", "of", "Makovytsia", "create", "a", "colorful", "tapestry", "during", "the", "spring", "season."],
    ["Mist-shrouded", "Petros", "adds", "an", "air", "of", "mystery", "to", "the", "Carpathians,", "captivating", "all", "who", "visit."],
    ["Meditating", "by", "the", "serene", "Shpici", "mountain", "is", "a", "soul-soothing", "experience", "for", "nature", "lovers."],
    ["Winter", "activities", "in", "the", "Carpathian", "Mountains,", "including", "Hoverla,", "attract", "snow", "sports", "enthusiasts."],
    ["The", "snow-capped", "peaks", "of", "Sinyak", "provide", "a", "striking", "contrast", "against", "the", "clear", "winter", "sky."],
    ["Makovytsia", "meadows,", "buzzing", "with", "life,", "offer", "a", "haven", "for", "various", "flora", "and", "fauna."],
    ["Climbers", "conquer", "Petros'", "imposing", "cliffs,", "driven", "by", "the", "allure", "of", "its", "challenging", "ascent."],
    ["Shpici", "in", "its", "remote", "location,", "remains", "untouched", "and", "pristine,", "appealing", "to", "explorers."],
    ["The", "summit", "of", "Hoverla", "provides", "a", "mesmerizing", "panorama", "of", "the", "surrounding", "mountain", "ranges."],
    ["Valleys", "around", "Sinyak", "are", "adorned", "with", "pristine", "streams", "and", "picturesque", "waterfalls."],
    ["Makovytsia", "trails", "wind", "through", "ancient", "forests,", "revealing", "the", "mountain's", "rich", "biodiversity."],
    ["Mountaineering", "enthusiasts", "flock", "to", "Petros", "for", "its", "challenging", "and", "rewarding", "ascent."],
    ["Shpici", "alpine", "lakes,", "hidden", "away,", "offer", "a", "tranquil", "retreat", "for", "those", "seeking", "solitude."],
    ["Hoverla", "standing", "tall,", "is", "a", "testament", "to", "the", "natural", "wonders", "of", "the", "Carpathian", "Mountains."],
    ["Sinyak", "rugged", "beauty", "showcases", "the", "untamed", "wilderness", "found", "within", "the", "region."],
    ["Makovytsia", "meadows", "teem", "with", "the", "sounds", "of", "buzzing", "insects", "and", "chirping", "birds."],
    ["Petros", "steeped", "in", "local", "folklore,", "shares", "stories", "of", "a", "legendary", "figure", "and", "ancient", "traditions."],
    ["Shpici", "though", "less", "visited,", "enchants", "those", "who", "discover", "its", "serene", "beauty", "and", "tranquility."],
    ["Winter", "ascent", "of", "Hoverla", "unveils", "a", "magical", "and", "enchanting", "side", "of", "the", "mountain."],
    ["Sinyak", "bathed", "in", "the", "warm", "hues", "of", "the", "setting", "sun,", "becomes", "a", "captivating", "sight."],
    ["Makovytsia", "foothills", "are", "dotted", "with", "charming", "villages,", "offering", "warm", "hospitality", "to", "visitors."],
    ["The", "challenging", "climb", "of", "Petros", "rewards", "adventurers", "with", "breathtaking", "views", "of", "the", "Carpathians."],
    ["Shpici", "trails", "provide", "opportunities", "to", "encounter", "diverse", "wildlife,", "from", "deer", "to", "soaring", "eagles."],
    ["Hoverla", "slopes", "burst", "into", "vibrant", "wildflowers", "during", "the", "summer", "months,", "creating", "a", "colorful", "display."],
    ["Skilled", "rock", "climbers", "and", "bouldering", "enthusiasts", "conquer", "Sinyak's", "rocky", "outcrops."],
    ["Makovytsia", "accessible", "trails", "make", "it", "a", "suitable", "destination", "for", "hikers", "of", "all", "skill", "levels."],
    ["The", "summit", "of", "Petros,", "kissed", "by", "the", "first", "light", "of", "dawn,", "offers", "a", "magical", "and", "serene", "experience."],
    ["Shpici", "away", "from", "tourist", "crowds,", "serves", "as", "a", "peaceful", "escape", "for", "those", "seeking", "solitude."],
    ["The", "valleys", "surrounding", "Hoverla", "are", "home", "to", "unique", "plant", "species", "adapted", "to", "the", "mountainous", "climate."],
    ["Sinyak", "craggy", "peaks", "create", "a", "dramatic", "silhouette", "against", "the", "evening", "sky."],
    ["Makovytsia", "diverse", "ecosystem", "supports", "a", "variety", "of", "wildlife,", "from", "butterflies", "to", "elusive", "mammals."],
    ["Climbers", "worldwide", "are", "drawn", "to", "Petros", "for", "its", "reputation", "as", "a", "challenging", "and", "iconic", "ascent."],
    ["Shpici", "remote", "location", "provides", "ideal", "conditions", "for", "stargazing,", "revealing", "the", "wonders", "of", "the", "night", "sky."],
    ["Hoverla", "with", "its", "snow-covered", "slopes,", "transforms", "into", "a", "winter", "wonderland", "during", "the", "colder", "months."],
    ["Sinyak", "meandering", "trails", "lead", "to", "hidden", "viewpoints,", "rewarding", "hikers", "with", "stunning", "vistas."],
    ["Makovytsia", "alpine", "lakes", "reflect", "the", "majestic", "surrounding", "peaks,", "creating", "a", "mirror-like", "effect."],
    ["Petros", "ancient", "rock", "formations", "narrate", "a", "geological", "story", "spanning", "thousands", "of", "years."],
    ["Shpici", "with", "its", "untouched", "landscapes,", "serves", "as", "a", "haven", "for", "photographers", "capturing", "the", "raw", "beauty", "of", "nature."],
    ["Exploring", "the", "foothills", "of", "Hoverla", "unveils", "charming", "villages", "and", "a", "rich", "cultural", "heritage."],
    ["Sinyak", "with", "its", "challenging", "terrain,", "becomes", "a", "playground", "for", "adrenaline", "junkies", "seeking", "adventure."],
    ["Blanketed", "in", "snow", "during", "winter,", "Makovytsia", "transforms", "into", "a", "serene", "and", "peaceful", "destination."],
    ["Petros", "towering", "cliffs", "provide", "nesting", "grounds", "for", "birds,", "attracting", "birdwatchers", "to", "the", "area."],
    ["Shpici", "embraced", "by", "the", "tranquility", "of", "nature,", "invites", "visitors", "to", "disconnect", "and", "rejuvenate."],
]

a = "B-MOUNTAIN"
s = "I-MOUNTAIN"

labels = [
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", a, s, "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", "O", "O", "O", a, "O", "O", "O", "O", "O"],
    ["O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", "O", "O", "O", a, "O", "O", "O", "O"],
    ["O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", "O", "O", "O", a, "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    ["O", "O", "O", "O", "O", a, "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
    [a, "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"],
]


print(len(sentences))
t = 0
# print(len(labels))
for i in range(len(sentences)):
    t += 1
    if len(sentences[i]) != len(labels[i]):
        print(t)
        print(len(sentences[i]))
        print(len(labels[i]))
# Out:
# 100

# %%
import csv

# Specify the file name
file_name = 'dataset.csv'

headers = ["sentence_id", "words", "labels"]
# Writing to CSV file
with open(file_name, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Write the data
    writer.writerow(headers)
    
    for i in range(len(sentences)):
        for j in range(len(sentences[i])):
            row = [i, sentences[i][j], labels[i][j]]
            writer.writerow(row)

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    sentence_id    words      labels
# 0            0  Hoverla  B-MOUNTAIN
# 1            0      the           O
# 2            0  highest           O
# 3            0     peak           O
# 4            0       in           O

# %%
# Sentences that haven't been used for model 

test_sentences = [
    "Sinyak Mountain, with its challenging ascent, beckons climbers to conquer its majestic peaks.",
    "Makovytsia, framed by alpine meadows, is a haven for nature enthusiasts seeking solace.",
    "Petros, standing proudly against the horizon, invites adventurers to explore its untamed trails.",
    "Shpici, though less explored, holds its own unique charm for those seeking solitude in nature.",
    "Exploring the dense forests around Hoverla reveals the diverse flora and fauna inhabiting the region.",
    "Rock climbers are drawn to the thrilling adventure that Sinyak's rocky terrain provides.",
    "Makovytsia, surrounded by alpine meadows, is a picturesque destination for a relaxing getaway.",
    "Petros is often shrouded in mist, adding an air of mystery to its already majestic presence.",
    "Shpici's serene surroundings make it an ideal spot for meditation and self-reflection.",
    "Nestled in the Carpathians, Hoverla is a hotspot for both winter and summer outdoor activities.",
    "Sinyak's snow-capped peaks create a stunning contrast against the deep blue sky.",
    "Makovytsia, known for its wildflowers, becomes a vibrant tapestry during the spring season.",
    "Petros, with its imposing cliffs, is a popular destination for daredevil climbers.",
    "Shpici's remote location attracts intrepid explorers seeking untouched wilderness.",
    "Hoverla's summit provides an unobstructed panorama of the surrounding mountain range.",
    "Sinyak's valleys are home to pristine streams and cascading waterfalls, adding to its allure.",
    "Makovytsia's trails wind through ancient forests, revealing the mountain's rich biodiversity.",
    "Petros, with its challenging ascent, is a favorite among mountaineering enthusiasts.",
    "Shpici's alpine lakes are hidden gems, offering a peaceful retreat for nature lovers.",
    "Hoverla, standing tall, is a symbol of the natural beauty that the Carpathian Mountains hold.",
    "Sinyak's rugged beauty is a testament to the untamed wilderness found in the region.",
    "Makovytsia's meadows are alive with the buzzing sounds of insects and the chirping of birds.",
    "Petros, named after a legendary figure, is steeped in folklore and local traditions.",
    "Shpici, though less visited, captivates those who seek solitude and a connection with nature.",
    "Climbing Hoverla during the winter months provides a completely different but equally enchanting experience.",
    "Sinyak, bathed in the warm hues of the setting sun, is a sight to behold.",
    "Makovytsia's foothills are adorned with charming villages, welcoming visitors with hospitality.",
    "Petros, a challenging climb, rewards adventurers with unparalleled views of the Carpathians.",
    "Shpici's trails offer a chance to encounter diverse wildlife, from elusive deer to soaring eagles.",
    "Hoverla's slopes are adorned with vibrant wildflowers during the summer months.",
    "Sinyak's rocky outcrops are a playground for skilled rock climbers and bouldering enthusiasts.",
    "Makovytsia, with its accessible trails, is suitable for hikers of all skill levels.",
    "Petros' summit, kissed by the first light of dawn, is a magical moment for early risers.",
    "Shpici, hidden away from the tourist crowds, provides a tranquil escape for those seeking solitude.",
    "The valleys surrounding Hoverla are home to unique plant species adapted to the mountainous climate.",
    "Sinyak's craggy peaks are silhouetted against the evening sky, creating a dramatic scene.",
    "Makovytsia's diverse ecosystem supports a variety of wildlife, from butterflies to elusive mammals.",
    "Petros, with its challenging ascent, attracts climbers from around the world.",
    "Shpici's remote location allows for stargazing, offering a clear view of the night sky.",
    "Hoverla, with its snow-covered slopes, transforms into a winter wonderland during the colder months.",
    "Sinyak's meandering trails lead to hidden viewpoints, rewarding hikers with stunning vistas.",
    "Makovytsia's alpine lakes reflect the surrounding peaks, creating a mirror-like effect.",
    "Petros' ancient rock formations tell a geological story that spans thousands of years.",
    "Shpici, with its untouched landscapes, is a haven for photographers capturing the raw beauty of nature.",
    "Exploring Hoverla's foothills reveals charming villages and a rich cultural heritage.",
    "Sinyak, with its challenging terrain, is a playground for adrenaline junkies seeking adventure.",
    "Makovytsia, blanketed in snow during winter, is a serene and peaceful destination.",
    "Petros' towering cliffs provide nesting grounds for birds, creating a birdwatcher's paradise.",
    "Shpici, embraced by the tranquility of nature, invites visitors to disconnect and rejuvenate.", 
    "The Carpathian Mountains, home to Hoverla, are a paradise for nature lovers and adventure seekers alike.",
    "Climbing Sinyak Mountain is a challenging but rewarding experience, offering stunning views from the summit.",
    "Makovytsia, surrounded by lush greenery, is a sanctuary for those seeking a peaceful escape in the mountains.",
    "Petros, standing tall and proud, is a symbol of strength and resilience in the Carpathians.",
    "Shpici, hidden in the shadows, reveals its beauty to those who venture off the beaten path.",
    "Explorers in Hoverla's dense forests may encounter rare species, making it a hotspot for biodiversity.",
    "Rock climbers are drawn to the adrenaline-pumping challenges presented by Sinyak's rugged terrain.",
    "Makovytsia, embraced by alpine meadows, is a canvas of colors during the blooming season.",
    "Petros, often shrouded in mist, has an aura of mystery that adds to its allure.",
    "Shpici's tranquil surroundings make it a perfect spot for meditation and contemplation.",
    "Located in the heart of the Carpathians, Hoverla attracts outdoor enthusiasts in every season.",
    "Sinyak's snow-capped peaks create a breathtaking scene against the winter sky.",
    "In Makovytsia, the arrival of spring transforms the mountain into a vibrant and lively landscape.",
    "Petros, with its towering cliffs, challenges climbers to conquer its formidable heights.",
    "Shpici's remote location offers a sense of solitude and a chance to connect with nature.",
    "Reaching the summit of Hoverla rewards hikers with panoramic views of the surrounding peaks.",
    "Sinyak's valleys are adorned with crystal-clear streams and cascading waterfalls, enhancing its natural beauty.",
    "Makovytsia's trails wind through ancient forests, revealing the mountain's ecological richness.",
    "Petros, with its challenging ascent, is a favorite among avid mountaineers seeking a thrill.",
    "Shpici's alpine lakes, hidden in pristine settings, are gems waiting to be discovered.",
    "Hoverla, a majestic peak, serves as an emblem of the unparalleled beauty of the Carpathian Mountains.",
    "Sinyak's rugged beauty epitomizes the untamed spirit of the wilderness in the region.",
    "Makovytsia's meadows come alive with the symphony of buzzing insects and singing birds.",
    "Petros, named after a legendary figure, holds the echoes of ancient tales and traditions.",
    "Shpici, off the beaten path, captivates those who appreciate the untouched allure of nature.",
    "Winter ascent of Hoverla reveals a magical and enchanting side of the mountain, covered in snow.",
    "As the sun sets, Sinyak bathes in warm hues, creating a mesmerizing spectacle for onlookers.",
    "Makovytsia's foothills are dotted with charming villages, each telling its own story.",
    "The challenging climb of Petros promises breathtaking vistas and a sense of accomplishment.",
    "Shpici's trails provide opportunities to spot diverse wildlife, from deer to majestic eagles.",
    "Hoverla's slopes burst into a riot of colors during the summer, adorned with vibrant wildflowers.",
    "Skilled climbers and bouldering enthusiasts explore Sinyak's rocky outcrops and challenging cliffs.",
    "Makovytsia, with its accessible trails, caters to hikers of all skill levels and preferences.",
    "Petros' summit, illuminated by the first light of dawn, offers a magical and serene experience.",
    "Shpici, hidden from tourist crowds, invites visitors to a tranquil escape into nature's embrace.",
    "The valleys surrounding Hoverla harbor unique plant species adapted to the demanding mountain climate.",
    "Sinyak's craggy peaks create a striking silhouette against the canvas of the evening sky.",
    "Makovytsia's diverse ecosystem sustains a plethora of wildlife, from delicate butterflies to elusive mammals.",
    "Climbers worldwide are drawn to Petros, enticed by its reputation as an iconic and challenging ascent.",
    "Shpici's remote location facilitates stargazing, offering a pristine view of the night sky's wonders.",
    "During winter, Hoverla transforms into a fairy-tale-like landscape, adorned with glistening snow.",
    "Sinyak's meandering trails lead to hidden viewpoints, treating hikers to breathtaking panoramic vistas.",
    "Makovytsia's alpine lakes mirror the majestic peaks, creating a captivating mirror-like reflection.",
    "Petros' ancient rock formations narrate a geological tale that spans thousands of years.",
    "Shpici, with its untouched landscapes, provides a haven for photographers capturing nature's raw beauty.",
    "Exploring Hoverla's foothills unveils charming villages and a rich tapestry of cultural heritage.",
    "Sinyak, with its challenging terrain, becomes a playground for adrenaline junkies seeking an adventure rush.",
    "Blanketed in snow during winter, Makovytsia exudes a serene and tranquil atmosphere.",
    "Petros' towering cliffs serve as nesting grounds for various birds, creating a paradise for birdwatchers.",
    "Shpici, embraced by the tranquility of nature, extends an invitation for visitors to disconnect and rejuvenate."
]
